# %% [markdown]
# Automobile sounds were recorded through our mobile phones.
# Steps followed for each audio sound (Audacity):
#
# 1. Normalize
# 2. Noise Reduction (eg bird noises, horns, chats) - except of messy soundwaves
# 2. Resample to 8k
# 3. Stereo to Mono
# 4. Trim to 30sec
#
# ctrl+e/ctrl+f -> zoom in/zoom out

# %% [markdown]
# Difficulties:
#
# 1. Lots of noise in our samples (human talking, walking, bird singing, etc)
# 2. Multiple automobiles passing by makes it hard to predict their actual number
# 3. Single lane VS Highway VS Crossroads "spot"
# 4. Microphone vertical VS horizontal to the road (eg bridge)

# %% [markdown]
# # RNN

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import zipfile
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')
import tensorflow
from tensorflow.keras.layers import LSTM, Dense
import numpy as np
import statistics
import soundfile as sf
from google.colab import drive
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split, KFold

# %% [markdown]
# ## Upload initial dataset (DOES NOT NEED TO RE-RUN)

# %% [markdown]
# The following cell is not needed to re-run so you can skip it. We just run it once in order to download the initial dataset which is stored in a google storage bucket.

# %%
# download the dataset (zipped file)
# !wget --no-check-certificate \
    https://storage.googleapis.com/machine_learning_for_multimodal_data/UpdatedRecordings.zip \
    -O /tmp/UpdatedRecordings.zip

# extract the downloaded dataset to a local directory: /tmp
local_zip = '/tmp/UpdatedRecordings.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/dataset')
zip_ref.close()
# Out:
# --2021-07-01 18:52:21--  https://storage.googleapis.com/machine_learning_for_multimodal_data/UpdatedRecordings.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 2607:f8b0:400e:c06::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 401201421 (383M) [application/x-zip-compressed]
# Saving to: ‘/tmp/UpdatedRecordings.zip’
#
# /tmp/UpdatedRecordi 100%[===================>] 382.62M   183MB/s    in 2.1s
#
# 2021-07-01 18:52:23 (183 MB/s) - ‘/tmp/UpdatedRecordings.zip’ saved [401201421/401201421]

# %%
# !ls /tmp/dataset/UpdatedRecordings

# %% [markdown]
# ## Create sub-folders for training and validation(DOES NOT NEED TO RE-RUN)

# %% [markdown]
# The following cell is not needed to re-run so you can skip it. We just run it once in order create the training and validation folders by splitting the initial dataset that downloaded above.

# %%
recordingsPath = '/tmp/dataset/UpdatedRecordings/'
training_dataset_len=round((len(os.listdir(os.path.join(recordingsPath))))*0.5)
num_of_iterations=0
for recording in os.listdir(recordingsPath):
  y, sr = librosa.load(recordingsPath+recording,sr=8000)
  if num_of_iterations<training_dataset_len:
    sf.write('/content/drive/My Drive/Multimodal_Dataset/training/'+os.path.splitext(recording)[0]+'.wav',y,sr)
    num_of_iterations=num_of_iterations+1
  else:
    sf.write('/content/drive/My Drive/Multimodal_Dataset/validation/'+os.path.splitext(recording)[0]+'.wav',y,sr)

# %% [markdown]
# ## Upload splitted dataset (Re-Run)

# %%
# download the dataset (zipped file)
# !wget --no-check-certificate \
    https://storage.googleapis.com/multimodal_dataset/Multimodal_Dataset.zip \
    -O /tmp/Multimodal_Dataset.zip

# extract the downloaded dataset to a local directory: /tmp
local_zip = '/tmp/Multimodal_Dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/dataset')
zip_ref.close()
# Out:
# --2021-07-05 21:54:25--  https://storage.googleapis.com/multimodal_dataset/Multimodal_Dataset.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 74.125.142.128, 2607:f8b0:400e:c09::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73793582 (70M) [application/x-zip-compressed]
# Saving to: ‘/tmp/Multimodal_Dataset.zip’
#
# /tmp/Multimodal_Dat 100%[===================>]  70.38M  63.1MB/s    in 1.1s
#
# 2021-07-05 21:54:27 (63.1 MB/s) - ‘/tmp/Multimodal_Dataset.zip’ saved [73793582/73793582]

# %%
# !ls /tmp/dataset/Multimodal_Dataset/validation/

# %% [markdown]
# # Raw Audio Augmentation (DOES NOT NEED TO RE-RUN)

# %% [markdown]
# ## Noise Addition

# %% [markdown]
# This process involves addition of noise i.e. white noise to the sample. White noises are random samples distributed at regular intervals with mean of 0 and standard deviation of 1.

# %%
'''
Noise addition using normal distribution with mean = 0 and std =1
Permissible noise factor value = x > 0.004
'''
drive.mount('/content/drive')
recordingsPath = '/tmp/dataset/Multimodal_Dataset/training/'
for recording in os.listdir(recordingsPath):
  y, sr = librosa.load(recordingsPath+recording)
  wav_wn = y + 0.009*np.random.normal(0,1,len(y))
  sf.write('/content/drive/My Drive/Augmented_audio_files/'+os.path.splitext(recording)[0]+'_aug_wn.wav',wav_wn,sr)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Time Shifting

# %% [markdown]
# Here we shift the wave by sample_rate/10 factor. This will move the wave to the right by given factor along time axis.
#
# For achieving this I have used numpy’s roll function to generate time shifting.

# %%
drive.mount('/content/drive')
recordingsPath = '/tmp/dataset/Multimodal_Dataset/training/'
for recording in os.listdir(recordingsPath):
  y, sr = librosa.load(recordingsPath+recording)
  wav_roll = np.roll(y,int(sr/10))
  sf.write('/content/drive/My Drive/Augmented_audio_files/'+os.path.splitext(recording)[0]+'_aug_tsh.wav',wav_roll,sr)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Pitch Shifting

# %% [markdown]
# It is a process of changing the pitch of sound without affect it’s speed.
#
# Again we are going to use librosa’s pitch_shift function. It takes wave samples, sample rate and number of steps through which pitch must be shifted. I found that number of steps between -5 to 5 are much favorable as per our dataset.

# %%
#pitch shifting of wav
for recording in os.listdir(recordingsPath):
  y, sr = librosa.load(recordingsPath+recording)
  wav_pitch_sf = librosa.effects.pitch_shift(y,sr,n_steps=4)
  sf.write('/content/drive/My Drive/Augmented_audio_files/'+os.path.splitext(recording)[0]+'_aug_pitch_sf.wav',wav_pitch_sf,sr)

# %% [markdown]
# # Visualizing a sample of original and augmented raw audio files

# %%
# download the dataset (zipped file)
# !wget --no-check-certificate \
    https://storage.googleapis.com/multimodal_for_plotting/multimodal_for_plotting.zip \
    -O /tmp/multimodal_for_plotting.zip

# extract the downloaded dataset to a local directory: /tmp
local_zip = '/tmp/multimodal_for_plotting.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/multimodal_for_plotting')
zip_ref.close()
# Out:
# --2021-07-03 20:08:14--  https://storage.googleapis.com/multimodal_for_plotting/multimodal_for_plotting.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 74.125.142.128, 173.194.202.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4105622 (3.9M) [application/x-zip-compressed]
# Saving to: ‘/tmp/multimodal_for_plotting.zip’
#
# /tmp/multimodal_for 100%[===================>]   3.92M  --.-KB/s    in 0.02s
#
# 2021-07-03 20:08:14 (240 MB/s) - ‘/tmp/multimodal_for_plotting.zip’ saved [4105622/4105622]

# %%
initial_wav, sr = librosa.load('/tmp/multimodal_for_plotting/multimodal_for_plotting/'+'5_recording172.wav',sr=8000)
aug_pitch_sf_wav, pitch_sf_sr = librosa.load('/tmp/multimodal_for_plotting/multimodal_for_plotting/'+'5_recording172_aug_pitch_sf.wav',sr=8000)
aug_tsh_wav, tsh_sr = librosa.load('/tmp/multimodal_for_plotting/multimodal_for_plotting/'+'5_recording172_aug_tsh.wav',sr=8000)
aug_wn_wav, wn_sr = librosa.load('/tmp/multimodal_for_plotting/multimodal_for_plotting/'+'5_recording172_aug_wn.wav',sr=8000)

# %%
def plot_spec(initial_data:np.array,initial_sr:int,aug_pitch_sf_data:np.array,pitch_sf_sr:int,aug_tsh_data:np.array,tsh_sr:int,aug_wn_data:np.array,wn_sr:int) -> None:
  '''
  Function for plotting spectrogram along with amplitude wave graph
  '''
  fig, ax = plt.subplots(2,2,figsize=(30,20))
  ax[0,0].title.set_text('Original wave file')
  ax[0,0].set_ylabel('Amplitude')
  ax[0,0].plot(initial_data)
  ax[0,1].title.set_text('Pitch Shift wave file')
  ax[0,1].set_ylabel('Amplitude')
  ax[0,1].plot(aug_pitch_sf_data)
  ax[1,0].title.set_text('Time Shift wave file')
  ax[1,0].set_ylabel('Amplitude')
  ax[1,0].plot(aug_tsh_data) 
  ax[1,1].title.set_text('White Noise wave file')
  ax[1,1].set_ylabel('Amplitude')
  ax[1,1].plot(aug_wn_data)    
plot_spec(initial_wav,sr,aug_pitch_sf_wav,pitch_sf_sr,aug_tsh_wav,tsh_sr,aug_wn_wav,wn_sr)

# %% [markdown]
# # Upload Augmented Training data

# %%
# download the dataset (zipped file)
# !wget --no-check-certificate \
    https://storage.googleapis.com/multimodal_training_augmented_data/training_augmented_data.zip \
    -O /tmp/training_augmented_data.zip

# extract the downloaded dataset to a local directory: /tmp
local_zip = '/tmp/training_augmented_data.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/dataset')
zip_ref.close()
# Out:
# --2021-07-05 21:54:33--  https://storage.googleapis.com/multimodal_training_augmented_data/training_augmented_data.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 173.194.202.128, 173.194.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338401938 (323M) [application/x-zip-compressed]
# Saving to: ‘/tmp/training_augmented_data.zip’
#
# /tmp/training_augme 100%[===================>] 322.72M   252MB/s    in 1.3s
#
# 2021-07-05 21:54:35 (252 MB/s) - ‘/tmp/training_augmented_data.zip’ saved [338401938/338401938]

# %%
# !ls /tmp/dataset/training_augmented_data/

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Feature Extraction (Training)

# %%
TrainingRecordingsPath='/tmp/dataset/training_augmented_data/'
# dictionary to store labels, and MFCCs
data_training = {
    "mfcc": [],
    "labels": []
    }
for recording in os.listdir(TrainingRecordingsPath):
  y, sr = librosa.load(TrainingRecordingsPath+recording,sr=8000)
  mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
  mfcc = mfcc.T
  data_training["mfcc"].append(mfcc.tolist())
  partitioned_string = recording.partition('_')
  label = partitioned_string[0]
  if int(label) <= 5:
    data_training["labels"].append(0)
  elif int(label) <= 10:
    data_training["labels"].append(1)
  elif int(label) <= 15:
    data_training["labels"].append(2)
  elif int(label) <= 20:
    data_training["labels"].append(3)
  elif int(label) <= 15:
    data_training["labels"].append(4)
  elif int(label) <= 20:
    data_training["labels"].append(5)  
  elif int(label) <= 25:
    data_training["labels"].append(6)
  else:
    data_training["labels"].append(7)

# %% [markdown]
# ## Feature Extraction (Test)

# %%
ValidationRecordingsPath= '/tmp/dataset/Multimodal_Dataset/validation/'
# dictionary to store labels, and MFCCs
data_test = {
    "mfcc": [],
    "labels": []
    }
for recording in os.listdir(ValidationRecordingsPath):
  y, sr = librosa.load(ValidationRecordingsPath+recording,sr=8000)
  mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
  mfcc = mfcc.T
  data_test["mfcc"].append(mfcc.tolist())
  partitioned_string = recording.partition('_')
  label = partitioned_string[0]
  if int(label) <= 5:
    data_test["labels"].append(0)
  elif int(label) <= 10:
    data_test["labels"].append(1)
  elif int(label) <= 15:
    data_test["labels"].append(2)
  elif int(label) <= 20:
    data_test["labels"].append(3)
  elif int(label) <= 15:
    data_test["labels"].append(4)
  elif int(label) <= 20:
    data_test["labels"].append(5)  
  elif int(label) <= 25:
    data_test["labels"].append(6)
  else:
    data_test["labels"].append(7)

# %% [markdown]
# ## Convert lists to numpy arrays

# %%
#convert lists to numpy arrays
X = np.array(data_training["mfcc"])
y = np.array(data_training["labels"])
X_test=np.array(data_test["mfcc"])
y_test = np.array(data_test["labels"])

# %%
X.shape
# Out:
# (344, 469, 40)

# %% [markdown]
# ## Build/Compile/Train the model

# %% [markdown]
# ### With cross validation

# %%
import tensorflow.keras as keras
"""Generates RNN-LSTM model
:param input_shape (tuple): Shape of input set
:return model: RNN-LSTM model
"""
input_shape = (X.shape[1], X.shape[2])
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []
# Define the K-fold Cross Validator
kfold = KFold(n_splits=5,shuffle=True)
# K-fold Cross Validation model evaluation
fold_no = 1
for train_index, test_index in kfold.split(X):
  X_train, X_val = X[train_index], X[test_index]
  y_train, y_val = y[train_index], y[test_index]
  # build network topology
  model = keras.Sequential()

  # 2 LSTM layers
  model.add(keras.layers.LSTM(128, input_shape=input_shape, return_sequences=True))
  model.add(keras.layers.LSTM(128))
  model.add(keras.layers.Dropout(0.3))

  # dense layer
  model.add(keras.layers.Dense(64, activation='relu'))
  model.add(keras.layers.Dropout(0.5))

  # output layer
  model.add(keras.layers.Dense(8, activation='softmax'))

  # simple early stopping
  # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
  # compile model
  optimiser = keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(optimizer=optimiser,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

  # model.summary()
  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  # train model
  history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=40, epochs=35, verbose=1,callbacks=[es])
  
  # evaluate the model
  _, train_acc = model.evaluate(X_train, y_train, verbose=0)
  _, val_acc = model.evaluate(X_val, y_val, verbose=0)
  print('Train: %.3f, Validation: %.3f' % (train_acc, val_acc))

  # plot loss - val loss
  plt.title("Train vs Validation loss")
  plt.plot(history.history['loss'], label='train')
  plt.plot(history.history['val_loss'], label='Validation')
  plt.legend()
  plt.show()

  # plot accuracy - val accuracy
  plt.title("Train vs Validation accuracy")
  plt.plot(history.history['accuracy'], label='train')
  plt.plot(history.history['val_accuracy'], label='Validation')
  plt.legend()
  plt.show()

  # Generate generalization metrics
  scores = model.evaluate(X_val, y_val, verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/35
# 7/7 [==============================] - 7s 169ms/step - loss: 2.1231 - accuracy: 0.1600 - val_loss: 2.0306 - val_accuracy: 0.2029
# Epoch 2/35
# 7/7 [==============================] - 0s 63ms/step - loss: 2.0287 - accuracy: 0.2145 - val_loss: 1.9449 - val_accuracy: 0.3188
# Epoch 3/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.9629 - accuracy: 0.2509 - val_loss: 1.8814 - val_accuracy: 0.3043
# Epoch 4/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8783 - accuracy: 0.3127 - val_loss: 1.8263 - val_accuracy: 0.3188
# Epoch 5/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7835 - accuracy: 0.3564 - val_loss: 1.7776 - val_accuracy: 0.3478
# Epoch 6/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8055 - accuracy: 0.3273 - val_loss: 1.7324 - val_accuracy: 0.4058
# Epoch 7/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7210 - accuracy: 0.3600 - val_loss: 1.6879 - val_accuracy: 0.4058
# Epoch 8/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.6734 - accuracy: 0.3818 - val_loss: 1.6461 - val_accuracy: 0.4493
# Epoch 9/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6108 - accuracy: 0.4291 - val_loss: 1.6072 - val_accuracy: 0.4783
# Epoch 10/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5607 - accuracy: 0.4945 - val_loss: 1.5714 - val_accuracy: 0.4783
# Epoch 11/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5263 - accuracy: 0.4909 - val_loss: 1.5392 - val_accuracy: 0.4928
# Epoch 12/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5027 - accuracy: 0.4800 - val_loss: 1.5109 - val_accuracy: 0.4928
# Epoch 13/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4693 - accuracy: 0.4945 - val_loss: 1.4836 - val_accuracy: 0.5217
# Epoch 14/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4799 - accuracy: 0.4473 - val_loss: 1.4571 - val_accuracy: 0.5072
# Epoch 15/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4294 - accuracy: 0.5309 - val_loss: 1.4402 - val_accuracy: 0.4783
# Epoch 16/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3855 - accuracy: 0.5273 - val_loss: 1.4216 - val_accuracy: 0.4928
# Epoch 17/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3207 - accuracy: 0.5564 - val_loss: 1.3915 - val_accuracy: 0.5217
# Epoch 18/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.2455 - accuracy: 0.5709 - val_loss: 1.3637 - val_accuracy: 0.5507
# Epoch 19/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2593 - accuracy: 0.5527 - val_loss: 1.3378 - val_accuracy: 0.5217
# Epoch 20/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.2220 - accuracy: 0.5782 - val_loss: 1.3150 - val_accuracy: 0.5507
# Epoch 21/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2154 - accuracy: 0.6073 - val_loss: 1.2973 - val_accuracy: 0.5797
# Epoch 22/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.1622 - accuracy: 0.5927 - val_loss: 1.2901 - val_accuracy: 0.5797
# Epoch 23/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1337 - accuracy: 0.6473 - val_loss: 1.2438 - val_accuracy: 0.5942
# Epoch 24/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1028 - accuracy: 0.6145 - val_loss: 1.2004 - val_accuracy: 0.6232
# Epoch 25/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1089 - accuracy: 0.6218 - val_loss: 1.1851 - val_accuracy: 0.6232
# Epoch 26/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9541 - accuracy: 0.6800 - val_loss: 1.1678 - val_accuracy: 0.6667
# Epoch 27/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9816 - accuracy: 0.6764 - val_loss: 1.1401 - val_accuracy: 0.6522
# Epoch 28/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.9655 - accuracy: 0.7055 - val_loss: 1.1158 - val_accuracy: 0.6667
# Epoch 29/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.8758 - accuracy: 0.7382 - val_loss: 1.1138 - val_accuracy: 0.6377
# Epoch 30/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8745 - accuracy: 0.7382 - val_loss: 1.1074 - val_accuracy: 0.6522
# Epoch 31/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8093 - accuracy: 0.7491 - val_loss: 1.1049 - val_accuracy: 0.6522
# Epoch 32/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7692 - accuracy: 0.7927 - val_loss: 1.0849 - val_accuracy: 0.6522
# Epoch 33/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7294 - accuracy: 0.7927 - val_loss: 1.0714 - val_accuracy: 0.6377
# Epoch 34/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.7208 - accuracy: 0.7855 - val_loss: 1.0623 - val_accuracy: 0.6232
# Epoch 35/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6556 - accuracy: 0.8000 - val_loss: 1.0543 - val_accuracy: 0.6522
# Train: 0.895, Validation: 0.652
# Score for fold 1: loss of 1.0543235540390015; accuracy of 65.21739363670349%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/35
# 7/7 [==============================] - 3s 166ms/step - loss: 2.2772 - accuracy: 0.0727 - val_loss: 2.1592 - val_accuracy: 0.1159
# Epoch 2/35
# 7/7 [==============================] - 0s 65ms/step - loss: 2.1705 - accuracy: 0.0909 - val_loss: 2.0878 - val_accuracy: 0.1739
# Epoch 3/35
# 7/7 [==============================] - 0s 64ms/step - loss: 2.1047 - accuracy: 0.1855 - val_loss: 2.0269 - val_accuracy: 0.2029
# Epoch 4/35
# 7/7 [==============================] - 0s 64ms/step - loss: 2.0314 - accuracy: 0.1855 - val_loss: 1.9739 - val_accuracy: 0.2754
# Epoch 5/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.9856 - accuracy: 0.2218 - val_loss: 1.9241 - val_accuracy: 0.3188
# Epoch 6/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.9394 - accuracy: 0.2582 - val_loss: 1.8801 - val_accuracy: 0.3623
# Epoch 7/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.8556 - accuracy: 0.3055 - val_loss: 1.8371 - val_accuracy: 0.4203
# Epoch 8/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8338 - accuracy: 0.3709 - val_loss: 1.7948 - val_accuracy: 0.4348
# Epoch 9/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8042 - accuracy: 0.3345 - val_loss: 1.7509 - val_accuracy: 0.4348
# Epoch 10/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7670 - accuracy: 0.3673 - val_loss: 1.7070 - val_accuracy: 0.4493
# Epoch 11/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6960 - accuracy: 0.4073 - val_loss: 1.6659 - val_accuracy: 0.4348
# Epoch 12/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6383 - accuracy: 0.4436 - val_loss: 1.6207 - val_accuracy: 0.4493
# Epoch 13/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6601 - accuracy: 0.4218 - val_loss: 1.5764 - val_accuracy: 0.4638
# Epoch 14/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5627 - accuracy: 0.4727 - val_loss: 1.5332 - val_accuracy: 0.4638
# Epoch 15/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5815 - accuracy: 0.4436 - val_loss: 1.4877 - val_accuracy: 0.4783
# Epoch 16/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5749 - accuracy: 0.4291 - val_loss: 1.4483 - val_accuracy: 0.5362
# Epoch 17/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4995 - accuracy: 0.5127 - val_loss: 1.4041 - val_accuracy: 0.5507
# Epoch 18/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4230 - accuracy: 0.4982 - val_loss: 1.3623 - val_accuracy: 0.5652
# Epoch 19/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4506 - accuracy: 0.5055 - val_loss: 1.3228 - val_accuracy: 0.6232
# Epoch 20/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4395 - accuracy: 0.5018 - val_loss: 1.2803 - val_accuracy: 0.6667
# Epoch 21/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3274 - accuracy: 0.5345 - val_loss: 1.2366 - val_accuracy: 0.6377
# Epoch 22/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2973 - accuracy: 0.5382 - val_loss: 1.2058 - val_accuracy: 0.6377
# Epoch 23/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2237 - accuracy: 0.5964 - val_loss: 1.1600 - val_accuracy: 0.6812
# Epoch 24/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2044 - accuracy: 0.5855 - val_loss: 1.1222 - val_accuracy: 0.6812
# Epoch 25/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2289 - accuracy: 0.5927 - val_loss: 1.0918 - val_accuracy: 0.6812
# Epoch 26/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.0868 - accuracy: 0.6727 - val_loss: 1.0559 - val_accuracy: 0.7101
# Epoch 27/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1199 - accuracy: 0.6436 - val_loss: 1.0143 - val_accuracy: 0.7101
# Epoch 28/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.0181 - accuracy: 0.6764 - val_loss: 0.9731 - val_accuracy: 0.6522
# Epoch 29/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9688 - accuracy: 0.7055 - val_loss: 0.9516 - val_accuracy: 0.6812
# Epoch 30/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.9525 - accuracy: 0.7200 - val_loss: 0.9268 - val_accuracy: 0.7101
# Epoch 31/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9333 - accuracy: 0.6909 - val_loss: 0.8960 - val_accuracy: 0.6812
# Epoch 32/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8949 - accuracy: 0.7382 - val_loss: 0.8620 - val_accuracy: 0.7101
# Epoch 33/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8661 - accuracy: 0.7527 - val_loss: 0.8378 - val_accuracy: 0.7101
# Epoch 34/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7769 - accuracy: 0.8073 - val_loss: 0.8097 - val_accuracy: 0.7246
# Epoch 35/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8064 - accuracy: 0.7927 - val_loss: 0.7613 - val_accuracy: 0.7971
# Train: 0.909, Validation: 0.797
# Score for fold 2: loss of 0.7613015174865723; accuracy of 79.71014380455017%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/35
# 7/7 [==============================] - 4s 158ms/step - loss: 2.0613 - accuracy: 0.1636 - val_loss: 1.9155 - val_accuracy: 0.2899
# Epoch 2/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.9714 - accuracy: 0.2145 - val_loss: 1.8221 - val_accuracy: 0.4493
# Epoch 3/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.9199 - accuracy: 0.2727 - val_loss: 1.7384 - val_accuracy: 0.4928
# Epoch 4/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8263 - accuracy: 0.2982 - val_loss: 1.6649 - val_accuracy: 0.5217
# Epoch 5/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8050 - accuracy: 0.3091 - val_loss: 1.5991 - val_accuracy: 0.5217
# Epoch 6/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7001 - accuracy: 0.4255 - val_loss: 1.5408 - val_accuracy: 0.4928
# Epoch 7/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6839 - accuracy: 0.3964 - val_loss: 1.4852 - val_accuracy: 0.4928
# Epoch 8/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.6415 - accuracy: 0.3964 - val_loss: 1.4375 - val_accuracy: 0.5072
# Epoch 9/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5689 - accuracy: 0.4327 - val_loss: 1.3934 - val_accuracy: 0.5507
# Epoch 10/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5352 - accuracy: 0.4436 - val_loss: 1.3409 - val_accuracy: 0.5652
# Epoch 11/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4793 - accuracy: 0.4836 - val_loss: 1.2968 - val_accuracy: 0.5942
# Epoch 12/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4826 - accuracy: 0.4327 - val_loss: 1.2531 - val_accuracy: 0.5942
# Epoch 13/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4670 - accuracy: 0.4364 - val_loss: 1.2182 - val_accuracy: 0.6087
# Epoch 14/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4119 - accuracy: 0.4436 - val_loss: 1.1827 - val_accuracy: 0.6232
# Epoch 15/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.3973 - accuracy: 0.4691 - val_loss: 1.1518 - val_accuracy: 0.6522
# Epoch 16/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.2788 - accuracy: 0.5564 - val_loss: 1.1037 - val_accuracy: 0.6522
# Epoch 17/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2843 - accuracy: 0.5309 - val_loss: 1.0658 - val_accuracy: 0.6522
# Epoch 18/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2141 - accuracy: 0.5455 - val_loss: 1.0324 - val_accuracy: 0.6377
# Epoch 19/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2412 - accuracy: 0.5600 - val_loss: 1.0069 - val_accuracy: 0.6667
# Epoch 20/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1664 - accuracy: 0.5709 - val_loss: 0.9744 - val_accuracy: 0.6667
# Epoch 21/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.1367 - accuracy: 0.5818 - val_loss: 0.9545 - val_accuracy: 0.6667
# Epoch 22/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.1375 - accuracy: 0.6218 - val_loss: 0.9270 - val_accuracy: 0.6812
# Epoch 23/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.0049 - accuracy: 0.6691 - val_loss: 0.9054 - val_accuracy: 0.6522
# Epoch 24/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.0094 - accuracy: 0.6255 - val_loss: 0.8935 - val_accuracy: 0.6522
# Epoch 25/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.0296 - accuracy: 0.6509 - val_loss: 0.8843 - val_accuracy: 0.6522
# Epoch 26/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.9560 - accuracy: 0.6800 - val_loss: 0.8554 - val_accuracy: 0.6667
# Epoch 27/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.9099 - accuracy: 0.6764 - val_loss: 0.8361 - val_accuracy: 0.6667
# Epoch 28/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.8495 - accuracy: 0.7127 - val_loss: 0.8300 - val_accuracy: 0.6522
# Epoch 29/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.8758 - accuracy: 0.7018 - val_loss: 0.8284 - val_accuracy: 0.6812
# Epoch 30/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.7669 - accuracy: 0.7455 - val_loss: 0.8109 - val_accuracy: 0.6957
# Epoch 31/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.8121 - accuracy: 0.7164 - val_loss: 0.8378 - val_accuracy: 0.7246
# Epoch 32/35
# 7/7 [==============================] - 0s 65ms/step - loss: 0.7243 - accuracy: 0.7709 - val_loss: 0.7929 - val_accuracy: 0.7391
# Epoch 33/35
# 7/7 [==============================] - 0s 66ms/step - loss: 0.7302 - accuracy: 0.7673 - val_loss: 0.7774 - val_accuracy: 0.7101
# Epoch 34/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6847 - accuracy: 0.7600 - val_loss: 0.7471 - val_accuracy: 0.7246
# Epoch 35/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6353 - accuracy: 0.7818 - val_loss: 0.7380 - val_accuracy: 0.7391
# Train: 0.905, Validation: 0.739
# Score for fold 3: loss of 0.7380234599113464; accuracy of 73.9130437374115%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Epoch 1/35
# 7/7 [==============================] - 3s 158ms/step - loss: 2.1853 - accuracy: 0.1491 - val_loss: 2.0876 - val_accuracy: 0.0870
# Epoch 2/35
# 7/7 [==============================] - 0s 64ms/step - loss: 2.0532 - accuracy: 0.1745 - val_loss: 1.9830 - val_accuracy: 0.2319
# Epoch 3/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.9756 - accuracy: 0.2364 - val_loss: 1.9029 - val_accuracy: 0.2609
# Epoch 4/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.9106 - accuracy: 0.2727 - val_loss: 1.8369 - val_accuracy: 0.2754
# Epoch 5/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8437 - accuracy: 0.2982 - val_loss: 1.7740 - val_accuracy: 0.3913
# Epoch 6/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7918 - accuracy: 0.2836 - val_loss: 1.7171 - val_accuracy: 0.4783
# Epoch 7/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7550 - accuracy: 0.3091 - val_loss: 1.6639 - val_accuracy: 0.5072
# Epoch 8/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7083 - accuracy: 0.3345 - val_loss: 1.6100 - val_accuracy: 0.6087
# Epoch 9/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6581 - accuracy: 0.3964 - val_loss: 1.5636 - val_accuracy: 0.5797
# Epoch 10/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6091 - accuracy: 0.4182 - val_loss: 1.5204 - val_accuracy: 0.5507
# Epoch 11/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5549 - accuracy: 0.4291 - val_loss: 1.4755 - val_accuracy: 0.5797
# Epoch 12/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.5053 - accuracy: 0.4436 - val_loss: 1.4368 - val_accuracy: 0.5362
# Epoch 13/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.4640 - accuracy: 0.4909 - val_loss: 1.3987 - val_accuracy: 0.5217
# Epoch 14/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4263 - accuracy: 0.4727 - val_loss: 1.3674 - val_accuracy: 0.5362
# Epoch 15/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4081 - accuracy: 0.4873 - val_loss: 1.3363 - val_accuracy: 0.5362
# Epoch 16/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4271 - accuracy: 0.4764 - val_loss: 1.3114 - val_accuracy: 0.5652
# Epoch 17/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3201 - accuracy: 0.5091 - val_loss: 1.2844 - val_accuracy: 0.5942
# Epoch 18/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3466 - accuracy: 0.4945 - val_loss: 1.2621 - val_accuracy: 0.6087
# Epoch 19/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3014 - accuracy: 0.4909 - val_loss: 1.2362 - val_accuracy: 0.5942
# Epoch 20/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1858 - accuracy: 0.5855 - val_loss: 1.2098 - val_accuracy: 0.5942
# Epoch 21/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.2308 - accuracy: 0.5600 - val_loss: 1.1804 - val_accuracy: 0.5942
# Epoch 22/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1927 - accuracy: 0.5891 - val_loss: 1.1539 - val_accuracy: 0.6087
# Epoch 23/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1814 - accuracy: 0.5891 - val_loss: 1.1273 - val_accuracy: 0.5942
# Epoch 24/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1345 - accuracy: 0.5964 - val_loss: 1.0993 - val_accuracy: 0.6087
# Epoch 25/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.0936 - accuracy: 0.6073 - val_loss: 1.0925 - val_accuracy: 0.5942
# Epoch 26/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.0185 - accuracy: 0.6473 - val_loss: 1.0641 - val_accuracy: 0.6377
# Epoch 27/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.0452 - accuracy: 0.6727 - val_loss: 1.0215 - val_accuracy: 0.6522
# Epoch 28/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9410 - accuracy: 0.7127 - val_loss: 0.9984 - val_accuracy: 0.6522
# Epoch 29/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8630 - accuracy: 0.7273 - val_loss: 0.9858 - val_accuracy: 0.6522
# Epoch 30/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8835 - accuracy: 0.7091 - val_loss: 0.9587 - val_accuracy: 0.6522
# Epoch 31/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7852 - accuracy: 0.7491 - val_loss: 0.9241 - val_accuracy: 0.6667
# Epoch 32/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7787 - accuracy: 0.7600 - val_loss: 0.9532 - val_accuracy: 0.6377
# Epoch 33/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7815 - accuracy: 0.7455 - val_loss: 0.9337 - val_accuracy: 0.6812
# Epoch 34/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.6999 - accuracy: 0.7745 - val_loss: 0.9296 - val_accuracy: 0.6957
# Epoch 35/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7196 - accuracy: 0.7491 - val_loss: 0.8755 - val_accuracy: 0.6957
# Train: 0.887, Validation: 0.696
# Score for fold 4: loss of 0.8755366802215576; accuracy of 69.5652186870575%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Epoch 1/35
# 7/7 [==============================] - 4s 165ms/step - loss: 2.0379 - accuracy: 0.1739 - val_loss: 2.0017 - val_accuracy: 0.1765
# Epoch 2/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.9164 - accuracy: 0.2609 - val_loss: 1.9303 - val_accuracy: 0.2794
# Epoch 3/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.8882 - accuracy: 0.2283 - val_loss: 1.8721 - val_accuracy: 0.3235
# Epoch 4/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.8747 - accuracy: 0.2754 - val_loss: 1.8222 - val_accuracy: 0.3235
# Epoch 5/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7609 - accuracy: 0.3841 - val_loss: 1.7779 - val_accuracy: 0.3235
# Epoch 6/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7382 - accuracy: 0.3333 - val_loss: 1.7383 - val_accuracy: 0.3235
# Epoch 7/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6226 - accuracy: 0.4275 - val_loss: 1.6959 - val_accuracy: 0.3235
# Epoch 8/35
# 7/7 [==============================] - 0s 65ms/step - loss: 1.5967 - accuracy: 0.4275 - val_loss: 1.6593 - val_accuracy: 0.3235
# Epoch 9/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.6021 - accuracy: 0.4384 - val_loss: 1.6263 - val_accuracy: 0.3235
# Epoch 10/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.5264 - accuracy: 0.4493 - val_loss: 1.5979 - val_accuracy: 0.3235
# Epoch 11/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4832 - accuracy: 0.4746 - val_loss: 1.5700 - val_accuracy: 0.3235
# Epoch 12/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4716 - accuracy: 0.4457 - val_loss: 1.5435 - val_accuracy: 0.3529
# Epoch 13/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4814 - accuracy: 0.4928 - val_loss: 1.5196 - val_accuracy: 0.3529
# Epoch 14/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.4049 - accuracy: 0.5000 - val_loss: 1.4967 - val_accuracy: 0.3676
# Epoch 15/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3610 - accuracy: 0.5254 - val_loss: 1.4746 - val_accuracy: 0.3971
# Epoch 16/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3660 - accuracy: 0.4891 - val_loss: 1.4543 - val_accuracy: 0.3971
# Epoch 17/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3238 - accuracy: 0.4891 - val_loss: 1.4318 - val_accuracy: 0.3971
# Epoch 18/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2637 - accuracy: 0.5290 - val_loss: 1.4132 - val_accuracy: 0.4118
# Epoch 19/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.3000 - accuracy: 0.5362 - val_loss: 1.3855 - val_accuracy: 0.4412
# Epoch 20/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2051 - accuracy: 0.5507 - val_loss: 1.3586 - val_accuracy: 0.4412
# Epoch 21/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.2653 - accuracy: 0.5399 - val_loss: 1.3450 - val_accuracy: 0.4412
# Epoch 22/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1983 - accuracy: 0.6196 - val_loss: 1.3242 - val_accuracy: 0.4412
# Epoch 23/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1104 - accuracy: 0.6304 - val_loss: 1.2965 - val_accuracy: 0.4559
# Epoch 24/35
# 7/7 [==============================] - 0s 64ms/step - loss: 1.1453 - accuracy: 0.5870 - val_loss: 1.2670 - val_accuracy: 0.4853
# Epoch 25/35
# 7/7 [==============================] - 0s 63ms/step - loss: 1.0861 - accuracy: 0.6196 - val_loss: 1.2424 - val_accuracy: 0.4853
# Epoch 26/35
# 7/7 [==============================] - 0s 63ms/step - loss: 1.0997 - accuracy: 0.6268 - val_loss: 1.2278 - val_accuracy: 0.5147
# Epoch 27/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9800 - accuracy: 0.6594 - val_loss: 1.2067 - val_accuracy: 0.5147
# Epoch 28/35
# 7/7 [==============================] - 0s 63ms/step - loss: 0.9985 - accuracy: 0.6630 - val_loss: 1.1907 - val_accuracy: 0.5735
# Epoch 29/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9691 - accuracy: 0.7101 - val_loss: 1.1674 - val_accuracy: 0.5882
# Epoch 30/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.9612 - accuracy: 0.6594 - val_loss: 1.1517 - val_accuracy: 0.6029
# Epoch 31/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.8951 - accuracy: 0.7210 - val_loss: 1.1367 - val_accuracy: 0.5882
# Epoch 32/35
# 7/7 [==============================] - 0s 64ms/step - loss: 0.7998 - accuracy: 0.7899 - val_loss: 1.1372 - val_accuracy: 0.6176
# Epoch 33/35
# 7/7 [==============================] - 0s 63ms/step - loss: 0.8531 - accuracy: 0.7464 - val_loss: 1.1029 - val_accuracy: 0.6618
# Epoch 34/35
# 7/7 [==============================] - 0s 63ms/step - loss: 0.7728 - accuracy: 0.7971 - val_loss: 1.0628 - val_accuracy: 0.6618
# Epoch 35/35
# 7/7 [==============================] - 0s 63ms/step - loss: 0.7569 - accuracy: 0.7717 - val_loss: 1.0657 - val_accuracy: 0.6618
# Train: 0.891, Validation: 0.662
# Score for fold 5: loss of 1.0656969547271729; accuracy of 66.17646813392639%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 1.0543235540390015 - Accuracy: 65.21739363670349%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.7613015174865723 - Accuracy: 79.71014380455017%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.7380234599113464 - Accuracy: 73.9130437374115%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.8755366802215576 - Accuracy: 69.5652186870575%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 1.0656969547271729 - Accuracy: 66.17646813392639%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 70.91645359992981 (+- 5.349413469512831)
# > Loss: 0.8989764332771302
# ------------------------------------------------------------------------

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 3/3 [==============================] - 0s 24ms/step - loss: 1.4758 - accuracy: 0.4302
#
# Test accuracy: 0.43023255467414856

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 469, 150)          114600
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 128)               142848
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 266,224
# Trainable params: 266,224
# Non-trainable params: 0
# _________________________________________________________________
